# %%
# print() -- This is output function.
# ye single line comment hai -- ctrl + /

print("Abhi")
# Out:
# Abhi

# %%
10 + 2 # shift + Enter
# Out:
# 12

# %%
3 - 7
# Out:
# -4

# %%
7 * 8
# Out:
# 56

# %%
10 / 2
# Out:
# 5.0

# %% [markdown]
# ## Variable -- It is a container which hold some value.

# %%
# Some ways to declare a variable :-
a = 2

b = 2.5

c = "Nikhil"

d = 2+5j

# %%
# Location of variable

# %%
print(id(a))
# Out:
# 140725036098504

# %%
# American Standard Code for Information Interchange (ASCII)
